# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib as pyplot

# %% [markdown]
# ### Step 2. Import the dataset Euro_2012_stats_TEAM

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
Euro_2012_Stats_Team = pd.read_csv("Euro_2012_stats_TEAM.csv")

euro12 = Euro_2012_Stats_Team

display(euro12)
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12_Goals = euro12["Goals"]
display("Goals",euro12_Goals)
# Out:
# 'Goals'
# 0      4.0
# 1      4.0
# 2      4.0
# 3      5.0
# 4      3.0
# 5     10.0
# 6      5.0
# 7      6.0
# 8      2.0
# 9      2.0
# 10     6.0
# 11     1.0
# 12     5.0
# 13    12.0
# 14     5.0
# 15     2.0
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# Name: Goals, dtype: float64

# %% [markdown]
# # Step 5. How many team participated in the Euro2012?

# %%
Teams = pd.value_counts(euro12['Team'])

Total_Teams = Teams

display("Total Teams In Euro Cup",len(Total_Teams),euro12["Team"])
# Out:
# 'Total Teams In Euro Cup'
# 17
# 0                                               Croatia
# 1                                        Czech Republic
# 2                                               Denmark
# 3                                               England
# 4                                                France
# 5                                               Germany
# 6                                                Greece
# 7                                                 Italy
# 8                                           Netherlands
# 9                                                Poland
# 10                                             Portugal
# 11                                  Republic of Ireland
# 12                                               Russia
# 13                                                Spain
# 14                                               Sweden
# 15                                              Ukraine
# ...

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
euro12
print("Total Colunms In Dataset",len(euro12.columns))
# Out:
# Total Colunms In Dataset 35

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12[['Team' , 'Yellow Cards' , 'Red Cards']]
display(discipline)
# Out:
#                                                  Team  Yellow Cards  Red Cards
# 0                                             Croatia           9.0        0.0
# 1                                      Czech Republic           7.0        0.0
# 2                                             Denmark           4.0        0.0
# 3                                             England           5.0        0.0
# 4                                              France           6.0        0.0
# 5                                             Germany           4.0        0.0
# 6                                              Greece           9.0        1.0
# 7                                               Italy          16.0        0.0
# 8                                         Netherlands           5.0        0.0
# 9                                              Poland           7.0        1.0
# 10                                           Portugal          12.0        0.0
# ...

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
Sorting_Teams_By_Red_Cards = euro12.sort_values(by=['Red Cards'] , ascending=False) 
display(Sorting_Teams_By_Red_Cards)
Sorting_Teams_By_Yellow_Cards = euro12.sort_values(by=['Yellow Cards'] , ascending=False) 
display(Sorting_Teams_By_Yellow_Cards)
# Out:
#                                                  Team  Goals  Shots on target  \
# 6                                              Greece    5.0              8.0
# 9                                              Poland    2.0             15.0
# 11                                Republic of Ireland    1.0              7.0
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# ...

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
Mean = euro12.mean(axis=1)
print("Mean Of All Teams","\n",Mean)
# Out:
# Mean Of All Teams
#  0     143.137931
# 1     192.066667
# 2     156.300000
# 3     193.233333
# 4     247.166667
# 5     325.100000
# 6     159.833333
# 7     366.166667
# 8     185.900000
# 9     140.366667
# 10    239.266667
# 11    112.433333
# 12    192.266667
# 13    491.000000
# 14    148.133333
# 15    156.700000
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# dtype: float64

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro12[euro12.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany   10.0             32.0              32.0            47.80%
# 13    Spain   12.0             42.0              33.0            55.90%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.60%                        80.0           2.0            1.0
# 13           16.00%                       100.0           0.0            1.0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                    0.0  ...        10.0                62.60%       63.0
# 13                   0.0  ...        15.0                93.80%      102.0
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5            49.0      12.0           4.0        0.0     15.0      15.0
# 13           83.0      19.0          11.0        0.0     17.0      17.0
#
#     Players Used
# 5           17.0
# 13          18.0
#
# ...

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
Searching_Team = euro12["Team"].str.startswith("G" , na = False)
display(euro12[Searching_Team])
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany   10.0             32.0              32.0            47.80%
# 6   Greece    5.0              8.0              18.0            30.70%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5           15.60%                        80.0           2.0            1.0
# 6           19.20%                        32.0           1.0            1.0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                   0.0  ...        10.0                62.60%       63.0
# 6                   1.0  ...        13.0                65.10%       67.0
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5           49.0      12.0           4.0        0.0     15.0      15.0
# 6           48.0      12.0           9.0        1.0     12.0      12.0
#
#    Players Used
# 5          17.0
# 6          20.0
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
print(euro12.columns[:7])
display(euro12[['Team' , 'Goals' , 'Shots on target' , 'Shots off target' , 'Shooting Accuracy' , '% Goals-to-shots' , 'Total shots (inc. Blocked)']])
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)'],
#       dtype='object')
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
print(euro12.columns[:-3])
euro12[['Team', 'Goals', 'Shots on target', 'Shots off target',
       'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
       'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
       'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
       'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
       'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
       'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
       'Offsides', 'Yellow Cards', 'Red Cards']]
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards'],
#       dtype='object')
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
display(euro12.loc[[3 , 7 , 12],['Team','Shooting Accuracy']])
# Out:
#        Team Shooting Accuracy
# 3   England            50.00%
# 7     Italy            43.00%
# 12   Russia            22.50%

# %% [markdown]
# ### Step 15. Use apply method on Goal Column to make a new column called Performance, using following conditions
#
# 1. If Goals are less than or equal to 2, peformance is **Below Avg**
# 2. If Goals are more than 2 and less than or equal to 5, peformance is **Average**
# 3. If Goals are more than 5 and less than or equal to 10, peformance is **Above Average**
# 4. If Goals are more than 10 then peformance is **Excellent**

# %%
def Team_Performance(x):
    for x in euro12["Goals"]:
        if x <= 2:
            x = "Performance Is Below Average"
            euro12["Performance"] = x
        elif x <= 5:
            x = "Performance Is Average"
            euro12["Performance"] = x
        elif x <= 10:
            x = "Performance Is Above Average"
            euro12["Performance"] = x
        elif x > 10:
            x = "Performance Is Exellent"
            euro12["Performance"] = x
        return euro12


euro12 = euro12.apply(Team_Performance(euro12),axis =0)
display(Team_Performance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a49c3f5be57b> in <module>
#      16
#      17
# ---> 18 euro12 = euro12.apply(Team_Performance(euro12),axis =0)
#      19 display(Team_Performance)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     147         # dispatch to agg
#     148         if is_list_like(self.f) or is_dict_like(self.f):
# --> 149             return self.obj.aggregate(self.f, axis=self.axis, *self.args, **self.kwds)
#     150
#     151         # all empty
#
# ...
